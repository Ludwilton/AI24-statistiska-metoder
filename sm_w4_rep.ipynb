# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path = "./data/Hitters.csv"

df = pd.read_csv(data_path)

# %%
df
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 0      293    66      1    30   29     14      1     293     66       1
# 1      315    81      7    24   38     39     14    3449    835      69
# 2      479   130     18    66   72     76      3    1624    457      63
# 3      496   141     20    65   78     37     11    5628   1575     225
# 4      321    87     10    39   42     30      2     396    101      12
# ..     ...   ...    ...   ...  ...    ...    ...     ...    ...     ...
# 317    497   127      7    65   48     37      5    2703    806      32
# 318    492   136      5    76   50     94     12    5511   1511      39
# 319    475   126      3    61   43     52      6    1700    433       7
# 320    573   144      9    85   60     78      8    3198    857      97
# 321    631   170      9    77   44     31     11    4908   1457      30
#
#      CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary  \
# ...

# %%
df.describe()
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  322.000000  322.000000  322.000000  322.000000  322.000000  322.000000
# mean   380.928571  101.024845   10.770186   50.909938   48.027950   38.742236
# std    153.404981   46.454741    8.709037   26.024095   26.166895   21.639327
# min     16.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    255.250000   64.000000    4.000000   30.250000   28.000000   22.000000
# 50%    379.500000   96.000000    8.000000   48.000000   44.000000   35.000000
# 75%    512.000000  137.000000   16.000000   69.000000   64.750000   53.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years       CAtBat        CHits      CHmRun        CRuns  \
# count  322.000000    322.00000   322.000000  322.000000   322.000000
# mean     7.444099   2648.68323   717.571429   69.490683   358.795031
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'AtBat'}>,
#         <Axes: title={'center': 'Hits'}>,
#         <Axes: title={'center': 'HmRun'}>,
#         <Axes: title={'center': 'Runs'}>],
#        [<Axes: title={'center': 'RBI'}>,
#         <Axes: title={'center': 'Walks'}>,
#         <Axes: title={'center': 'Years'}>,
#         <Axes: title={'center': 'CAtBat'}>],
#        [<Axes: title={'center': 'CHits'}>,
#         <Axes: title={'center': 'CHmRun'}>,
#         <Axes: title={'center': 'CRuns'}>,
#         <Axes: title={'center': 'CRBI'}>],
#        [<Axes: title={'center': 'CWalks'}>,
#         <Axes: title={'center': 'PutOuts'}>,
#         <Axes: title={'center': 'Assists'}>,
#         <Axes: title={'center': 'Errors'}>],
#        [<Axes: title={'center': 'Salary'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df["Salary"].hist(cumulative=True)
# Out:
# <Axes: >

# %%
df["Salary"].hist()
# Out:
# <Axes: >

# %%
# korrelation mellan kolumner


df[["AtBat","Hits","HmRun","Runs"]].corr()
# Out:
#           AtBat      Hits     HmRun      Runs
# AtBat  1.000000  0.967939  0.592198  0.913060
# Hits   0.967939  1.000000  0.562158  0.922187
# HmRun  0.592198  0.562158  1.000000  0.650988
# Runs   0.913060  0.922187  0.650988  1.000000

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

fig, ax = plt.subplots()
stats.probplot(df["Salary"].to_numpy(), plot=ax)
plt.show()

# %%
df[["AtBat", "Salary"]].boxplot()
# Out:
# <Axes: >

# %%
df = pd.read_csv("./data/Auto.csv")

df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
Y = df["mpg"]
X = df[["weight", "year"]]

X = np.column_stack([np.ones(Y.shape[0]), X])

# %%
# regression
b = np.linalg.pinv(X.T @ X) @ X.T @ Y

b
# Out:
# array([-1.46502372e+01, -6.65511211e-03,  7.62333856e-01])

# %%
# signifikant regression

k = len(b) - 1 # längden på b minus 1, antalet parametrar

n = Y.shape[0] # antal observationer (stickprovsstorlek, längden av y)

SSE = np.sum(np.square(Y - X @ b)) # Square sum of errors, vi multiplicerar våra förutsägelser med

var  = SSE/(n-k-1) # variansen

S = np.sqrt(var) # uppskattning av standardavvikelsen 



Syy = (n*np.sum(np.square(Y)) - np.square(np.sum(Y)))/n # total varians för Y

SSR = Syy - SSE # vi tar den faktiska variansen och tar bort den från sum of square errors, detta ger oss SSE(Sum of square regression)

TSS = np.sum(np.square(Y - np.mean(Y))) # total sum of squares
Sxx = (n*np.sum(np.square(X)) - np.square(np.sum(X)))/n

# ensidigt test
sig_statistic = (SSR/k)/S # vi delar SSE med antalet parametrar och dividerar med S

sig_statistic # stort värde = signifikant, vi kan förkasta nollhypotesen


# "vad är sannolikheten att vi ser detta värdet" # testar alla parametrar samtidigt
p_val = stats.f.sf(sig_statistic, k, n-k-1) # vi använder oss av f-fördelningen för att räkna ut p-värdet
p_val # sannolikheten att alla parametrar b skulle bara noll, i detta fall är det väldigt liten
# Out:
# 2.8504506581429946e-235

# %%
# Out:
# 0.9999999999999988

# %%
plt.scatter(X@b, Y)

# %%
Rsq = SSR/Syy # rsq = R^2
Rsq # 70% av variansen i Y kan förklaras av X
# Out:
# 0.8087475430653486

# %%
c = np.linalg.pinv(X.T @ X)*var # kovariansmatrisen

i = 1
b_statistic = b[i] / (S * np.sqrt(c[i,i])) # vi delar b med standardavvikelsen
p_b = 2*min(stats.t.cdf(b_statistic, n-k-1), 1 - stats.t.cdf(b_statistic, n-k-1)) # vi räknar ut p-värdet
p_b # sannolikheten att b är slumpmässigt är
# p_b sannolikheten att just b(i) skulle vara noll

# litet värde = signifikant, vi kan förkasta nollhypotesen
# stort värde = inte signifikant, vi kan inte förkasta nollhypotesen
# p-värdet är sannolikheten att vi ser detta värde om nollhypotesen är sann

# "year" är signifikant (1/8 på miljonen att vi ser detta värde om nollhypotesen är sann)
# "weight" är signifikant
# Out:
# 5.4888721756873685e-18
